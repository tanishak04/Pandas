# %% [markdown]
# adding columns

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\mohan\python\engineering-log\pandas\datasets\chatgpt_ka_dataset.csv")

# %%
print(data)
# Out:
#    EmployeeID     Name Department  Age  Salary  Experience       City  \
# 0         101    Alice         HR   25   35000           2      Delhi
# 1         102      Bob         IT   30   60000           6     Mumbai
# 2         103  Charlie         IT   28   55000           4  Bengaluru
# 3         104    David      Sales   35   50000           8      Delhi
# 4         105      Eva         HR   26   37000           3       Pune
# 5         106    Frank    Finance   40   70000          15    Chennai
# 6         107    Grace      Sales   32   52000           7     Mumbai
# 7         108    Helen         IT   29   58000           5  Hyderabad
# 8         109      Ian    Finance   38   68000          12      Delhi
# 9         110    Julia         HR   27   39000           2       Pune
#
#    PerformanceScore
# 0                88
# 1                92
# 2                79
# 3                85
# 4                91
# 5                95
# 6                76
# 7                89
# ...

# %%
data["bonus"]=data["Salary"]*1.05

# %%
print(data)
# Out:
#    EmployeeID     Name Department  Age  Salary  Experience       City  \
# 0         101    Alice         HR   25   35000           2      Delhi
# 1         102      Bob         IT   30   60000           6     Mumbai
# 2         103  Charlie         IT   28   55000           4  Bengaluru
# 3         104    David      Sales   35   50000           8      Delhi
# 4         105      Eva         HR   26   37000           3       Pune
# 5         106    Frank    Finance   40   70000          15    Chennai
# 6         107    Grace      Sales   32   52000           7     Mumbai
# 7         108    Helen         IT   29   58000           5  Hyderabad
# 8         109      Ian    Finance   38   68000          12      Delhi
# 9         110    Julia         HR   27   39000           2       Pune
#
#    PerformanceScore    bonus
# 0                88  36750.0
# 1                92  63000.0
# 2                79  57750.0
# 3                85  52500.0
# 4                91  38850.0
# ...

# %% [markdown]
# adding columns using insert(at a specific position)

# %%
data.insert(1,"enployee id",[100,200,300,400,500,600,700,800,900,1001])

# %%
print(data)
# Out:
#    EmployeeID  enployee id     Name Department  Age  Salary  Experience  \
# 0         101          100    Alice         HR   25   35000           2
# 1         102          200      Bob         IT   30   60000           6
# 2         103          300  Charlie         IT   28   55000           4
# 3         104          400    David      Sales   35   50000           8
# 4         105          500      Eva         HR   26   37000           3
# 5         106          600    Frank    Finance   40   70000          15
# 6         107          700    Grace      Sales   32   52000           7
# 7         108          800    Helen         IT   29   58000           5
# 8         109          900      Ian    Finance   38   68000          12
# 9         110         1001    Julia         HR   27   39000           2
#
#         City  PerformanceScore    bonus
# 0      Delhi                88  36750.0
# 1     Mumbai                92  63000.0
# 2  Bengaluru                79  57750.0
# ...

# %% [markdown]
# updating values

# %%
data.loc[4,"Salary"]=3000

# %%
print(data)
# Out:
#    EmployeeID  enployee id     Name Department  Age  Salary  Experience  \
# 0         101          100    Alice         HR   25   35000           2
# 1         102          200      Bob         IT   30   60000           6
# 2         103          300  Charlie         IT   28   55000           4
# 3         104          400    David      Sales   35   50000           8
# 4         105          500      Eva         HR   26    3000           3
# 5         106          600    Frank    Finance   40   70000          15
# 6         107          700    Grace      Sales   32   52000           7
# 7         108          800    Helen         IT   29   58000           5
# 8         109          900      Ian    Finance   38   68000          12
# 9         110         1001    Julia         HR   27   39000           2
#
#         City  PerformanceScore    bonus
# 0      Delhi                88  36750.0
# 1     Mumbai                92  63000.0
# 2  Bengaluru                79  57750.0
# ...

# %% [markdown]
# increasing all salary by 10%

# %%
data["Salary"]=data["Salary"]*1.5

# %%
print(data)
# Out:
#    EmployeeID     Name Department  Age    Salary  Experience       City  \
# 0         101    Alice         HR   25   52500.0           2      Delhi
# 1         102      Bob         IT   30   90000.0           6     Mumbai
# 2         103  Charlie         IT   28   82500.0           4  Bengaluru
# 3         104    David      Sales   35   75000.0           8      Delhi
# 4         105      Eva         HR   26   55500.0           3       Pune
# 5         106    Frank    Finance   40  105000.0          15    Chennai
# 6         107    Grace      Sales   32   78000.0           7     Mumbai
# 7         108    Helen         IT   29   87000.0           5  Hyderabad
# 8         109      Ian    Finance   38  102000.0          12      Delhi
# 9         110    Julia         HR   27   58500.0           2       Pune
#
#    PerformanceScore
# 0                88
# 1                92
# 2                79
# 3                85
# 4                91
# 5                95
# 6                76
# ...

# %% [markdown]
# removing columns

# %%
data.drop(columns="EmployeeID",inplace=True)

# %%
print(data)
# Out:
#       Name Department  Age  Salary  Experience       City  PerformanceScore
# 0    Alice         HR   25   35000           2      Delhi                88
# 1      Bob         IT   30   60000           6     Mumbai                92
# 2  Charlie         IT   28   55000           4  Bengaluru                79
# 3    David      Sales   35   50000           8      Delhi                85
# 4      Eva         HR   26   37000           3       Pune                91
# 5    Frank    Finance   40   70000          15    Chennai                95
# 6    Grace      Sales   32   52000           7     Mumbai                76
# 7    Helen         IT   29   58000           5  Hyderabad                89
# 8      Ian    Finance   38   68000          12      Delhi                94
# 9    Julia         HR   27   39000           2       Pune                82
