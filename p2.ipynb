# %%
import pandas as pd

# %%
data = {
    "Name": ["a", "b", "c", "d"],
    "Age": [10, 20, 30, 40],
    "City": ["x", "y", "z", "w"]
}

# %%
df=pd.DataFrame(data) #convert it into a data frame i.e 2 dimensional data

# %%
df.to_csv("made by code.csv")

# %%
df.to_csv("made_by_code_without_index.csv", index=False)

# %% [markdown]
# display rows from top usinf head and from bottom using tail deafult for both is 5

# %%
obj=pd.read_csv("made_by_code_without_index.csv")
print(obj.head(2))
# Out:
#   Name  Age City
# 0    a   10    x
# 1    b   20    y

# %%
print(obj.tail(2))
# Out:
#    EmployeeID   Name Department  Age  Salary  Experience   City  \
# 8         109    Ian    Finance   38   68000          12  Delhi
# 9         110  Julia         HR   27   39000           2   Pune
#
#    PerformanceScore
# 8                94
# 9                82

# %%
obj1=pd.read_csv("zyada_bada_dataset.csv")

# %%
print(obj1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...
