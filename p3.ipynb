# %%
import pandas as pd

# %%
data={
    "name":["x","y","z","as","ad","qw"],
    "age":[10,20,30,50,85,60],
    "city":["a","b","c","e","f","g"],
    "salary":[50000,80000,70000,90000,10000,30000]
}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#   name  age city  salary
# 0    x   10    a   50000
# 1    y   20    b   80000
# 2    z   30    c   70000
# 3   as   50    e   90000
# 4   ad   85    f   10000
# 5   qw   60    g   30000

# %%
print("Descriptive Statics")
print(df.describe())
# Out:
# Descriptive Statics
#              age        salary
# count   6.000000      6.000000
# mean   42.500000  55000.000000
# std    27.883687  30822.070015
# min    10.000000  10000.000000
# 25%    22.500000  35000.000000
# 50%    40.000000  60000.000000
# 75%    57.500000  77500.000000
# max    85.000000  90000.000000

# %%
df1=pd.read_csv(r"C:\Users\mohan\python\engineering-log\pandas\datasets\chatgpt_ka_datset.csv",encoding="latin1")

# %%
print(df1.shape,  df1.columns)
# Out:
# (10, 8) Index(['EmployeeID', 'Name', 'Department', 'Age', 'Salary', 'Experience',
#        'City', 'PerformanceScore'],
#       dtype='object')

# %%
df2=pd.DataFrame(df1)

# %%
print(df2)
# Out:
#    EmployeeID     Name Department  Age  Salary  Experience       City  \
# 0         101    Alice         HR   25   35000           2      Delhi
# 1         102      Bob         IT   30   60000           6     Mumbai
# 2         103  Charlie         IT   28   55000           4  Bengaluru
# 3         104    David      Sales   35   50000           8      Delhi
# 4         105      Eva         HR   26   37000           3       Pune
# 5         106    Frank    Finance   40   70000          15    Chennai
# 6         107    Grace      Sales   32   52000           7     Mumbai
# 7         108    Helen         IT   29   58000           5  Hyderabad
# 8         109      Ian    Finance   38   68000          12      Delhi
# 9         110    Julia         HR   27   39000           2       Pune
#
#    PerformanceScore
# 0                88
# 1                92
# 2                79
# 3                85
# 4                91
# 5                95
# 6                76
# 7                89
# ...

# %%
print(df2["Name"])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eva
# 5      Frank
# 6      Grace
# 7      Helen
# 8        Ian
# 9      Julia
# Name: Name, dtype: object

# %% [markdown]
# selecting multiple columns

# %%
print(df2[["Name","Age"]])
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   28
# 3    David   35
# 4      Eva   26
# 5    Frank   40
# 6    Grace   32
# 7    Helen   29
# 8      Ian   38
# 9    Julia   27

# %% [markdown]
# single filter

# %%
print(df2[df2["Age"]>35])
# Out:
#    EmployeeID   Name Department  Age  Salary  Experience     City  \
# 5         106  Frank    Finance   40   70000          15  Chennai
# 8         109    Ian    Finance   38   68000          12    Delhi
#
#    PerformanceScore
# 5                95
# 8                94

# %% [markdown]
# multi filter

# %%
print(df2[(df2["Age"]>=25) &( df2["Salary"]>50000)])
# Out:
#    EmployeeID     Name Department  Age  Salary  Experience       City  \
# 1         102      Bob         IT   30   60000           6     Mumbai
# 2         103  Charlie         IT   28   55000           4  Bengaluru
# 5         106    Frank    Finance   40   70000          15    Chennai
# 6         107    Grace      Sales   32   52000           7     Mumbai
# 7         108    Helen         IT   29   58000           5  Hyderabad
# 8         109      Ian    Finance   38   68000          12      Delhi
#
#    PerformanceScore
# 1                92
# 2                79
# 5                95
# 6                76
# 7                89
# 8                94
